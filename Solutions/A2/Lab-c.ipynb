# %% [markdown]
# ## Bernoulli Model Lab Work

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('basketball.csv', encoding='utf8', engine='python')
data.keys()
# Out:
# Index(['outlook', 'temp', 'humidity', 'windy', 'play'], dtype='object')

# %%
features = ['outlook', 'temp', 'humidity', 'windy']

# %%
oneHotEncoder = OneHotEncoder()
oneHotEncoder.fit(data[features])
oneHotData = oneHotEncoder.transform(data[features])

# %%
Xtrain,Xtest,Ytrain,Ytest = train_test_split(oneHotData,data['play'],test_size=0.3)

# %%
clf = BernoulliNB()

# %%
#进行K折交叉验证
cvs = cross_val_score(clf, oneHotData, data['play'], cv=4)
cvs.mean()
# Out:
# 0.7083333333333333

# %%
clf = BernoulliNB()
clf.fit(Xtrain, Ytrain)
# Out:
# BernoulliNB()

# %%
acc_score = clf.score(Xtest,Ytest)
print(acc_score)
# Out:
# 0.4

# %%
Y_pred = clf.predict(Xtest)
print(Y_pred)
# Out:
# ['no' 'no' 'yes' 'yes' 'no']

# %%
prob = clf.predict_proba(Xtest)
print(prob.shape)
# Out:
# (5, 2)

# %%
print(Xtest)
# Out:
#   (0, 0)	1.0
#   (0, 4)	1.0
#   (0, 6)	1.0
#   (0, 8)	1.0
#   (1, 0)	1.0
#   (1, 5)	1.0
#   (1, 6)	1.0
#   (1, 9)	1.0
#   (2, 1)	1.0
#   (2, 3)	1.0
#   (2, 7)	1.0
#   (2, 9)	1.0
#   (3, 2)	1.0
#   (3, 3)	1.0
#   (3, 7)	1.0
#   (3, 8)	1.0
#   (4, 2)	1.0
#   (4, 4)	1.0
#   (4, 6)	1.0
#   (4, 9)	1.0
